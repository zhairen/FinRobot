# %%
import autogen
from autogen.cache import Cache

from finrobot.utils import get_current_date, register_keys_from_json
from finrobot.data_source import FinnHubUtils, YFinanceUtils
from autogen import AssistantAgent, UserProxyAgent

from typing import Annotated

# %%
config_list = [
    {
        "model": "llama3",
        "base_url": "http://127.0.0.1:4000",
        "api_key": "ollama",
    }
]

llm_config = {"config_list": config_list, "timeout": 120, "temperature": 0}

# %%
register_keys_from_json("../config_api_keys")

analyst = AssistantAgent(
    name="Market_Analyst",
    llm_config=llm_config,
)

user_proxy = UserProxyAgent("user_proxy", code_execution_config=False, max_consecutive_auto_reply=1,  is_termination_msg=lambda x: x.get("content", "") and "TERMINATE" in x.get("content", ""),
    human_input_mode="NEVER")

# %%
from finrobot.toolkits import register_toolkits
tools = [
    {
        "function": YFinanceUtils.get_stock_data,
        #"function": FinnHubUtils.get_company_news,
        "name": "get_stock_news",
        "description": "retrieve stock information related to designated company"
    }
]
register_toolkits(tools, analyst, user_proxy)

# %%
company = "apple"
date='2024-07-01'

# %%
user_proxy.initiate_chat(analyst, message=f"What is stock price available for {company} from {date} upon {get_current_date()}.")
# Out:
# user_proxy (to Market_Analyst):
#
# What is stock price available for apple from 2024-07-01 upon 2025-07-23.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /root/anaconda3/envs/fintech/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/openai/_base_client.py:979, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     978 try:
# --> 979     response = self._client.send(
#     980         request,
#     981         stream=stream or self._should_stream_response_body(request=request),
#     982         **kwargs,
#     983     )
#     984 except httpx.TimeoutException as err:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 user_proxy.initiate_chat(analyst, message=f"What is stock price available for {company} from {date} upon {get_current_date()}.")
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1106, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1104     else:
#    1105         msg2send = self.generate_init_message(message, **kwargs)
# -> 1106     self.send(msg2send, recipient, silent=silent)
#    1107 summary = self._summarize_chat(
#    1108     summary_method,
#    1109     summary_args,
#    1110     recipient,
#    1111     cache=cache,
#    1112 )
#    1113 for agent in [self, recipient]:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:741, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     739 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     740 if valid:
# --> 741     recipient.receive(message, self, request_reply, silent)
#     742 else:
#     743     raise ValueError(
#     744         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     745     )
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:906, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     904 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     905     return
# --> 906 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     907 if reply is not None:
#     908     self.send(reply, sender, silent=silent)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2060, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2058     continue
#    2059 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2060     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2061     if logging_enabled():
#    2062         log_event(
#    2063             self,
#    2064             "reply_func_executed",
#    (...)
#    2068             reply=reply,
#    2069         )
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1428, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1426 if messages is None:
#    1427     messages = self._oai_messages[sender]
# -> 1428 extracted_response = self._generate_oai_reply_from_client(
#    1429     client, self._oai_system_message + messages, self.client_cache
#    1430 )
#    1431 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1447, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1444         all_messages.append(message)
#    1446 # TODO: #1143 handle token limit exceeded error
# -> 1447 response = llm_client.create(
#    1448     context=messages[-1].pop("context", None), messages=all_messages, cache=cache, agent=self
#    1449 )
#    1450 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1452 if extracted_response is None:
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/oai/client.py:832, in OpenAIWrapper.create(self, **config)
#     830 try:
#     831     request_ts = get_current_ts()
# --> 832     response = client.create(params)
#     833 except APITimeoutError as err:
#     834     logger.debug(f"config {i} timed out", exc_info=True)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/autogen/oai/client.py:401, in OpenAIClient.create(self, params)
#     399     params = params.copy()
#     400     params["stream"] = False
# --> 401     response = completions.create(**params)
#     403 return response
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:1087, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1044 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1045 def create(
#    1046     self,
#    (...)
#    1084     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1085 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1086     validate_response_format(response_format)
# -> 1087     return self._post(
#    1088         "/chat/completions",
#    1089         body=maybe_transform(
#    1090             {
#    1091                 "messages": messages,
#    1092                 "model": model,
#    1093                 "audio": audio,
#    1094                 "frequency_penalty": frequency_penalty,
#    1095                 "function_call": function_call,
#    1096                 "functions": functions,
#    1097                 "logit_bias": logit_bias,
#    1098                 "logprobs": logprobs,
#    1099                 "max_completion_tokens": max_completion_tokens,
#    1100                 "max_tokens": max_tokens,
#    1101                 "metadata": metadata,
#    1102                 "modalities": modalities,
#    1103                 "n": n,
#    1104                 "parallel_tool_calls": parallel_tool_calls,
#    1105                 "prediction": prediction,
#    1106                 "presence_penalty": presence_penalty,
#    1107                 "reasoning_effort": reasoning_effort,
#    1108                 "response_format": response_format,
#    1109                 "seed": seed,
#    1110                 "service_tier": service_tier,
#    1111                 "stop": stop,
#    1112                 "store": store,
#    1113                 "stream": stream,
#    1114                 "stream_options": stream_options,
#    1115                 "temperature": temperature,
#    1116                 "tool_choice": tool_choice,
#    1117                 "tools": tools,
#    1118                 "top_logprobs": top_logprobs,
#    1119                 "top_p": top_p,
#    1120                 "user": user,
#    1121                 "web_search_options": web_search_options,
#    1122             },
#    1123             completion_create_params.CompletionCreateParamsStreaming
#    1124             if stream
#    1125             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1126         ),
#    1127         options=make_request_options(
#    1128             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1129         ),
#    1130         cast_to=ChatCompletion,
#    1131         stream=stream or False,
#    1132         stream_cls=Stream[ChatCompletionChunk],
#    1133     )
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/openai/_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /root/anaconda3/envs/fintech/lib/python3.10/site-packages/openai/_base_client.py:1011, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1008         continue
#    1010     log.debug("Raising connection error")
# -> 1011     raise APIConnectionError(request=request) from err
#    1013 log.debug(
#    1014     'HTTP Response: %s %s "%i %s" %s',
#    1015     request.method,
#    (...)
#    1019     response.headers,
#    1020 )
#    1021 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
